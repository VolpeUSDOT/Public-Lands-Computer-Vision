# %%
import os
import time
from datetime import datetime
import pandas as pd

import cv2
import yt_dlp
from ultralytics import YOLO
from collections import defaultdict
import supervision as sv

# %%
video_url = "https://www.youtube.com/watch?v=0Pg3S6s76IE"  # Youtube URL northbound Paso Del Norte

# %%
def get_stream_url(youtube_url):
    ydl_opts = {
        'quiet': True,
        'skip_download': True,
        'no_warnings': True,
        'force_generic_extractor': False,
        'format': 'best[ext=mp4][protocol^=http]/best'
    }
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        info = ydl.extract_info(youtube_url, download=False)
        formats = info.get('formats', [info])
        # prefer video-only best mp4 OR best overall
        for f in reversed(formats):
            if f.get('vcodec', '') != 'none' and f.get('acodec', '') == 'none' and 'url' in f:
                return f['url']
        # fallback: best available format
        return formats[-1]['url']

# %%
# Load the YOLO model
model = YOLO('yolo11l.pt')

class_list = model.names 

# Dictionary to store object counts by class
class_counts = defaultdict(int)

# the line
line_y_red_end = 590  # Red line position
line_y_red_start = 960  # Red line position


def capture_frames(stream_url):

    # Open the video file
    cap = cv2.VideoCapture(stream_url)
    get_fps = cap.get(cv2.CAP_PROP_FPS)
    print(get_fps)

    frame_count = 0
    resultsList = []

    while True:
        
        ret, frame = cap.read() # read each frame one by one
        
        if not ret: #when there are no more frames, break
            # Release resources on way out of while loop
            print("on way to first break")
            cap.release()
            cv2.destroyAllWindows()
            break

        # method to set frame position with cap.set and skip frames wasn't really working
        # going to try this method to process only every tenth frame... let's try every 15th now
        frame_count += 1
        if frame_count % 15 != 0:
            continue  # Skip frames that are not multiples of 15
        
        # Run YOLO tracking on the frame
        results = model.track(frame, classes = [1,2,3,5,6,7], persist=True) 
        #print(results)

        # Ensure results are not empty
        if results[0].boxes.data is not None:
            # Get the detected boxes, their class indices, and track IDs
            boxes = results[0].boxes.xyxy.cpu()
            track_ids = results[0].boxes.id.int().cpu().tolist()
            class_indices = results[0].boxes.cls.int().cpu().tolist()
            confidences = results[0].boxes.conf.cpu()

            cv2.line(frame, (400, line_y_red_end), (1450, line_y_red_end), (0, 0, 255), 2)
            cv2.line(frame, (400, line_y_red_start), (1450, line_y_red_start), (0, 0, 255), 2)

            cv2.line(frame, (400, line_y_red_end), (400, line_y_red_start), (0, 0, 255), 2)
            cv2.line(frame, (940, line_y_red_end), (940, line_y_red_start), (0, 0, 255), 2)
            cv2.line(frame, (1100, line_y_red_end), (1100, line_y_red_start), (0, 0, 255), 2)
            cv2.line(frame, (1450, line_y_red_end), (1450, line_y_red_start), (0, 0, 255), 2)
            #cv2.putText(frame, 'Red Line', (690, line_y_red - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1, cv2.LINE_AA)
        
            # Loop through each detected object
            for box, track_id, class_idx, conf in zip(boxes, track_ids, class_indices, confidences):
                x1, y1, x2, y2 = map(int, box)
                cx = (x1 + x2) // 2  # Calculate the center point
                cy = (y1 + y2) // 2            

                class_name = class_list[class_idx]

                cv2.circle(frame, (cx, cy), 4, (0, 0, 255), -1)
                
                cv2.putText(frame, f"ID: {track_id} {class_name}", (x1, y1 - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 255), 2)
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2) 

                dfKeyFeatures = pd.DataFrame({'id' : [track_id], 
                                              'class' : [class_name], 
                                              'confidence' : [conf], 
                                              'cx' : [cx], 
                                              'cy' : [cy], 
                                              'timestamp' : [cap.get(cv2.CAP_PROP_POS_MSEC)]})
                resultsList.append(dfKeyFeatures)

            # Display the counts on the frame
            y_offset = 50
            for class_name, count in class_counts.items():
                cv2.putText(frame, f"{class_name}: {count}", (50, y_offset),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)
                y_offset += 30

        ### Save frame    
        # prep timestamp for file name
        current_datetime = datetime.now().strftime("%Y-%m-%d %H-%M-%S")
        # Save as PNG
        # YOUR FILE PATH HERE
        filename =r'c:\Users\Nineveh.OConnell\OneDrive - DOT OST\Documents\code\Border-Bottleneck-Management\support_scripts\captured_pngs'
        cv2.imwrite(f"{filename}/frame_{str(current_datetime)}.png", frame)
        print(f"Saved frame {current_datetime}")

        #i += 1
        get_curr_pos = cap.get(cv2.CAP_PROP_POS_FRAMES)
        print(get_curr_pos)
        #cap.set(cv2.CAP_PROP_POS_FRAMES, get_curr_pos + 15) # skip frames, 1 corresponds to the propid index, 10 skips 10 frames I believe
        print(cap.get(cv2.CAP_PROP_POS_FRAMES))

        # Show the frame
        cv2.imshow("YOLO Object Tracking & Counting", frame)    

        # Exit loop if 'q' key is pressed
        if cv2.waitKey(1) & 0xFF == ord('q'): #removed:  
            # Release resources on way out of while loop
            print("on way to second break")
            cap.release()
            cv2.destroyAllWindows()
            break

    # Save output metrics as data frame
    combined_df = pd.concat(resultsList)
    # YOUR FILE PATH HERE
    datafolder =r'c:\Users\Nineveh.OConnell\OneDrive - DOT OST\Documents\code\Border-Bottleneck-Management\support_scripts\captured_coords'
    combined_df.to_csv(f"{datafolder}/data_download_export.csv", index=False) 


if __name__ == "__main__":
    stream_url = get_stream_url(video_url)
    print("Stream URL:", stream_url)
    capture_frames(stream_url)
# Out:
# Stream URL: https://manifest.googlevideo.com/api/manifest/hls_playlist/expire/1753476757/ei/NZqDaLiENq3PvOMP7vnD6Ao/ip/152.122.255.5/id/0Pg3S6s76IE.2/itag/270/source/yt_live_broadcast/requiressl/yes/ratebypass/yes/live/1/sgovp/gir%3Dyes%3Bitag%3D137/rqh/1/hls_chunk_host/rr2---sn-vgqsrnzd.googlevideo.com/xpc/EgVo2aDSNQ%3D%3D/playlist_duration/30/manifest_duration/30/bui/AY1jyLNnvjrfhZtkZSVsEPJkBoC6Zq2Eqd2tm8j_r1uOMHO669ESAee3f6Ll1wylv8GEaxlu69EqRwVX/spc/l3OVKXheNW4rFceUPi1rq9Q2Q6nABGA0ZT0YzOZlVXuMNwszB2ZZaqjbaj4maA/vprv/1/playlist_type/DVR/met/1753455158,/mh/sg/mm/44/mn/sn-vgqsrnzd/ms/lva/mv/u/mvi/2/pl/16/rms/lva,lva/dover/13/pacing/0/short_key/1/keepalive/yes/fexp/51542235/mt/1753454385/sparams/expire,ei,ip,id,itag,source,requiressl,ratebypass,live,sgovp,rqh,xpc,playlist_duration,manifest_duration,bui,spc,vprv,playlist_type/sig/AJfQdSswRQIgekz1FU_dQ6yPTKXGBzwI_-hen-Aoqn2PpwSUmKHUQugCIQDMmpQW444X0mdaSovbWVZKYLIfWCzC4cwHcxJ4wpgPGQ%3D%3D/lsparams/hls_chunk_host,met,mh,mm,mn,ms,mv,mvi,pl,rms/lsig/APaTxxMwRQIhANDgEcPpSDrmyfrqvcOP36Nvr3JRcqYGyz06ciU3tAFeAiBfp0yfh3rCYvoEGLEP4kdnn94hwyTI5PB8qJ6WvMyK7w%3D%3D/playlist/index.m3u8
# 30.0
#
# 0: 384x640 16 cars, 1 truck, 336.8ms
# Speed: 2.6ms preprocess, 336.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-52-43
# 15.0
# 15.0
#
# 0: 384x640 16 cars, 1 truck, 296.8ms
# Speed: 1.9ms preprocess, 296.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-52-43
# 30.0
# 30.0
#
# 0: 384x640 16 cars, 1 truck, 314.8ms
# Speed: 1.9ms preprocess, 314.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-52-44
# 45.0
# 45.0
#
# 0: 384x640 16 cars, 1 truck, 293.0ms
# Speed: 1.7ms preprocess, 293.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-52-44
# 60.0
# 60.0
#
# 0: 384x640 16 cars, 1 truck, 277.8ms
# Speed: 1.7ms preprocess, 277.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-52-44
# 75.0
# 75.0
#
# 0: 384x640 16 cars, 1 truck, 294.8ms
# Speed: 1.9ms preprocess, 294.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-52-45
# 90.0
# 90.0
#
# 0: 384x640 16 cars, 1 truck, 312.6ms
# Speed: 1.6ms preprocess, 312.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-52-45
# 105.0
# 105.0
#
# 0: 384x640 16 cars, 1 truck, 315.5ms
# Speed: 1.7ms preprocess, 315.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-52-46
# 120.0
# 120.0
#
# 0: 384x640 16 cars, 1 truck, 294.7ms
# Speed: 1.7ms preprocess, 294.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-52-46
# 135.0
# 135.0
#
# 0: 384x640 16 cars, 1 truck, 293.1ms
# Speed: 1.5ms preprocess, 293.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-52-47
# 150.0
# 150.0
#
# 0: 384x640 17 cars, 1 truck, 299.0ms
# Speed: 2.2ms preprocess, 299.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-52-47
# 165.0
# 165.0
#
# 0: 384x640 17 cars, 1 truck, 274.7ms
# Speed: 1.6ms preprocess, 274.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-52-48
# 180.0
# 180.0
#
# 0: 384x640 17 cars, 1 truck, 304.2ms
# Speed: 2.1ms preprocess, 304.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-52-48
# 195.0
# 195.0
#
# 0: 384x640 17 cars, 1 truck, 328.1ms
# Speed: 2.4ms preprocess, 328.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-52-49
# 210.0
# 210.0
#
# 0: 384x640 17 cars, 1 truck, 303.0ms
# Speed: 2.6ms preprocess, 303.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-52-49
# 225.0
# 225.0
#
# 0: 384x640 17 cars, 1 truck, 314.7ms
# Speed: 2.6ms preprocess, 314.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-52-50
# 240.0
# 240.0
#
# 0: 384x640 18 cars, 1 truck, 303.6ms
# Speed: 2.2ms preprocess, 303.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-52-50
# 255.0
# 255.0
#
# 0: 384x640 18 cars, 1 truck, 320.3ms
# Speed: 2.7ms preprocess, 320.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-52-51
# 270.0
# 270.0
#
# 0: 384x640 18 cars, 1 truck, 311.8ms
# Speed: 2.5ms preprocess, 311.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-52-51
# 285.0
# 285.0
#
# 0: 384x640 18 cars, 1 truck, 309.2ms
# Speed: 1.8ms preprocess, 309.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-52-52
# 300.0
# 300.0
#
# 0: 384x640 18 cars, 1 truck, 320.7ms
# Speed: 2.5ms preprocess, 320.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-52-53
# 315.0
# 315.0
#
# 0: 384x640 19 cars, 1 truck, 303.4ms
# Speed: 2.4ms preprocess, 303.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-52-53
# 330.0
# 330.0
#
# 0: 384x640 18 cars, 2 trucks, 312.1ms
# Speed: 1.8ms preprocess, 312.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-52-54
# 345.0
# 345.0
#
# 0: 384x640 19 cars, 1 truck, 328.1ms
# Speed: 2.2ms preprocess, 328.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-52-54
# 360.0
# 360.0
#
# 0: 384x640 19 cars, 1 truck, 310.6ms
# Speed: 2.2ms preprocess, 310.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-52-55
# 375.0
# 375.0
#
# 0: 384x640 18 cars, 2 trucks, 308.6ms
# Speed: 2.2ms preprocess, 308.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-52-55
# 390.0
# 390.0
#
# 0: 384x640 18 cars, 2 trucks, 332.3ms
# Speed: 2.5ms preprocess, 332.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-52-56
# 405.0
# 405.0
#
# 0: 384x640 18 cars, 2 trucks, 339.2ms
# Speed: 2.2ms preprocess, 339.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-52-56
# 420.0
# 420.0
#
# 0: 384x640 18 cars, 2 trucks, 323.7ms
# Speed: 2.3ms preprocess, 323.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-52-57
# 435.0
# 435.0
#
# 0: 384x640 19 cars, 1 truck, 338.4ms
# Speed: 2.3ms preprocess, 338.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-52-58
# 450.0
# 450.0
#
# 0: 384x640 19 cars, 1 truck, 340.1ms
# Speed: 2.3ms preprocess, 340.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-52-58
# 465.0
# 465.0
#
# 0: 384x640 18 cars, 2 trucks, 335.1ms
# Speed: 2.3ms preprocess, 335.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-52-59
# 480.0
# 480.0
#
# 0: 384x640 18 cars, 2 trucks, 322.0ms
# Speed: 2.4ms preprocess, 322.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-52-59
# 495.0
# 495.0
#
# 0: 384x640 18 cars, 2 trucks, 315.4ms
# Speed: 2.3ms preprocess, 315.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-00
# 510.0
# 510.0
#
# 0: 384x640 18 cars, 2 trucks, 315.4ms
# Speed: 2.3ms preprocess, 315.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-00
# 525.0
# 525.0
#
# 0: 384x640 17 cars, 3 trucks, 352.2ms
# Speed: 2.1ms preprocess, 352.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-01
# 540.0
# 540.0
#
# 0: 384x640 18 cars, 2 trucks, 319.0ms
# Speed: 2.7ms preprocess, 319.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-01
# 555.0
# 555.0
#
# 0: 384x640 18 cars, 1 truck, 326.5ms
# Speed: 3.1ms preprocess, 326.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-02
# 570.0
# 570.0
#
# 0: 384x640 18 cars, 2 trucks, 302.6ms
# Speed: 2.5ms preprocess, 302.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-02
# 585.0
# 585.0
#
# 0: 384x640 18 cars, 2 trucks, 317.9ms
# Speed: 2.3ms preprocess, 317.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-03
# 600.0
# 600.0
#
# 0: 384x640 17 cars, 3 trucks, 315.9ms
# Speed: 2.4ms preprocess, 315.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-04
# 615.0
# 615.0
#
# 0: 384x640 16 cars, 4 trucks, 320.8ms
# Speed: 2.2ms preprocess, 320.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-04
# 630.0
# 630.0
#
# 0: 384x640 18 cars, 2 trucks, 323.0ms
# Speed: 2.5ms preprocess, 323.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-05
# 645.0
# 645.0
#
# 0: 384x640 19 cars, 2 trucks, 324.9ms
# Speed: 2.6ms preprocess, 324.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-05
# 660.0
# 660.0
#
# 0: 384x640 18 cars, 3 trucks, 313.2ms
# Speed: 2.3ms preprocess, 313.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-06
# 675.0
# 675.0
#
# 0: 384x640 18 cars, 4 trucks, 318.7ms
# Speed: 2.7ms preprocess, 318.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-06
# 690.0
# 690.0
#
# 0: 384x640 16 cars, 4 trucks, 323.6ms
# Speed: 2.6ms preprocess, 323.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-07
# 705.0
# 705.0
#
# 0: 384x640 17 cars, 2 trucks, 326.7ms
# Speed: 2.4ms preprocess, 326.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-07
# 720.0
# 720.0
#
# 0: 384x640 19 cars, 3 trucks, 318.9ms
# Speed: 2.3ms preprocess, 318.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-08
# 735.0
# 735.0
#
# 0: 384x640 17 cars, 3 trucks, 311.9ms
# Speed: 1.9ms preprocess, 311.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-09
# 750.0
# 750.0
#
# 0: 384x640 18 cars, 2 trucks, 326.1ms
# Speed: 2.5ms preprocess, 326.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-09
# 765.0
# 765.0
#
# 0: 384x640 18 cars, 2 trucks, 337.6ms
# Speed: 2.1ms preprocess, 337.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-10
# 780.0
# 780.0
#
# 0: 384x640 18 cars, 2 trucks, 325.2ms
# Speed: 2.5ms preprocess, 325.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-10
# 795.0
# 795.0
#
# 0: 384x640 18 cars, 2 trucks, 306.5ms
# Speed: 2.8ms preprocess, 306.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-11
# 810.0
# 810.0
#
# 0: 384x640 18 cars, 2 trucks, 327.6ms
# Speed: 2.2ms preprocess, 327.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-11
# 825.0
# 825.0
#
# 0: 384x640 18 cars, 2 trucks, 324.6ms
# Speed: 2.4ms preprocess, 324.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-12
# 840.0
# 840.0
#
# 0: 384x640 18 cars, 2 trucks, 317.2ms
# Speed: 2.6ms preprocess, 317.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-12
# 855.0
# 855.0
#
# 0: 384x640 18 cars, 2 trucks, 326.5ms
# Speed: 2.2ms preprocess, 326.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-13
# 870.0
# 870.0
#
# 0: 384x640 18 cars, 2 trucks, 323.2ms
# Speed: 2.2ms preprocess, 323.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-13
# 885.0
# 885.0
#
# 0: 384x640 18 cars, 2 trucks, 315.8ms
# Speed: 1.7ms preprocess, 315.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-14
# 900.0
# 900.0
#
# 0: 384x640 16 cars, 3 trucks, 314.5ms
# Speed: 1.9ms preprocess, 314.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-15
# 915.0
# 915.0
#
# 0: 384x640 16 cars, 5 trucks, 319.5ms
# Speed: 2.5ms preprocess, 319.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-15
# 930.0
# 930.0
#
# 0: 384x640 18 cars, 3 trucks, 316.3ms
# Speed: 2.6ms preprocess, 316.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-16
# 945.0
# 945.0
#
# 0: 384x640 16 cars, 4 trucks, 320.0ms
# Speed: 2.6ms preprocess, 320.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-16
# 960.0
# 960.0
#
# 0: 384x640 18 cars, 2 trucks, 327.8ms
# Speed: 2.2ms preprocess, 327.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-17
# 975.0
# 975.0
#
# 0: 384x640 17 cars, 3 trucks, 332.9ms
# Speed: 2.3ms preprocess, 332.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-17
# 990.0
# 990.0
#
# 0: 384x640 17 cars, 3 trucks, 327.8ms
# Speed: 2.4ms preprocess, 327.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-18
# 1005.0
# 1005.0
#
# 0: 384x640 18 cars, 3 trucks, 335.4ms
# Speed: 2.3ms preprocess, 335.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-18
# 1020.0
# 1020.0
#
# 0: 384x640 18 cars, 3 trucks, 312.0ms
# Speed: 2.4ms preprocess, 312.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-19
# 1035.0
# 1035.0
#
# 0: 384x640 17 cars, 2 trucks, 326.2ms
# Speed: 2.1ms preprocess, 326.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-20
# 1050.0
# 1050.0
#
# 0: 384x640 20 cars, 1 truck, 329.4ms
# Speed: 2.3ms preprocess, 329.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-20
# 1065.0
# 1065.0
#
# 0: 384x640 20 cars, 2 trucks, 332.6ms
# Speed: 2.3ms preprocess, 332.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-21
# 1080.0
# 1080.0
#
# 0: 384x640 21 cars, 1 truck, 342.3ms
# Speed: 2.1ms preprocess, 342.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-21
# 1095.0
# 1095.0
#
# 0: 384x640 19 cars, 1 truck, 332.6ms
# Speed: 2.5ms preprocess, 332.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-22
# 1110.0
# 1110.0
#
# 0: 384x640 19 cars, 2 trucks, 320.5ms
# Speed: 2.3ms preprocess, 320.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-22
# 1125.0
# 1125.0
#
# 0: 384x640 19 cars, 2 trucks, 325.6ms
# Speed: 2.9ms preprocess, 325.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-23
# 1140.0
# 1140.0
#
# 0: 384x640 21 cars, 1 truck, 313.7ms
# Speed: 2.7ms preprocess, 313.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-23
# 1155.0
# 1155.0
#
# 0: 384x640 21 cars, 1 truck, 316.5ms
# Speed: 2.5ms preprocess, 316.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-24
# 1170.0
# 1170.0
#
# 0: 384x640 19 cars, 1 truck, 324.3ms
# Speed: 2.5ms preprocess, 324.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-24
# 1185.0
# 1185.0
#
# 0: 384x640 19 cars, 2 trucks, 331.7ms
# Speed: 2.5ms preprocess, 331.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-25
# 1200.0
# 1200.0
#
# 0: 384x640 18 cars, 1 truck, 321.7ms
# Speed: 2.3ms preprocess, 321.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-26
# 1215.0
# 1215.0
#
# 0: 384x640 19 cars, 2 trucks, 318.1ms
# Speed: 2.4ms preprocess, 318.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-26
# 1230.0
# 1230.0
#
# 0: 384x640 19 cars, 2 trucks, 329.2ms
# Speed: 2.1ms preprocess, 329.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-27
# 1245.0
# 1245.0
#
# 0: 384x640 19 cars, 2 trucks, 313.1ms
# Speed: 2.5ms preprocess, 313.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-27
# 1260.0
# 1260.0
#
# 0: 384x640 19 cars, 2 trucks, 318.7ms
# Speed: 2.5ms preprocess, 318.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-28
# 1275.0
# 1275.0
#
# 0: 384x640 20 cars, 2 trucks, 317.7ms
# Speed: 2.7ms preprocess, 317.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-28
# 1290.0
# 1290.0
#
# 0: 384x640 20 cars, 2 trucks, 341.4ms
# Speed: 2.0ms preprocess, 341.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-29
# 1305.0
# 1305.0
#
# 0: 384x640 20 cars, 2 trucks, 333.3ms
# Speed: 2.2ms preprocess, 333.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-29
# 1320.0
# 1320.0
#
# 0: 384x640 20 cars, 3 trucks, 331.3ms
# Speed: 1.9ms preprocess, 331.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-30
# 1335.0
# 1335.0
#
# 0: 384x640 20 cars, 3 trucks, 326.2ms
# Speed: 2.1ms preprocess, 326.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-31
# 1350.0
# 1350.0
#
# 0: 384x640 19 cars, 3 trucks, 318.0ms
# Speed: 2.6ms preprocess, 318.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-31
# 1365.0
# 1365.0
#
# 0: 384x640 19 cars, 3 trucks, 313.5ms
# Speed: 2.3ms preprocess, 313.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-32
# 1380.0
# 1380.0
#
# 0: 384x640 19 cars, 3 trucks, 407.4ms
# Speed: 2.5ms preprocess, 407.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-32
# 1395.0
# 1395.0
#
# 0: 384x640 19 cars, 3 trucks, 330.3ms
# Speed: 2.1ms preprocess, 330.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-33
# 1410.0
# 1410.0
#
# 0: 384x640 19 cars, 3 trucks, 333.5ms
# Speed: 1.8ms preprocess, 333.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-33
# 1425.0
# 1425.0
#
# 0: 384x640 19 cars, 3 trucks, 346.1ms
# Speed: 2.6ms preprocess, 346.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-34
# 1440.0
# 1440.0
#
# 0: 384x640 19 cars, 3 trucks, 314.8ms
# Speed: 2.2ms preprocess, 314.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-34
# 1455.0
# 1455.0
#
# 0: 384x640 19 cars, 3 trucks, 315.2ms
# Speed: 1.7ms preprocess, 315.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-35
# 1470.0
# 1470.0
#
# 0: 384x640 20 cars, 3 trucks, 298.5ms
# Speed: 1.9ms preprocess, 298.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved frame 2025-07-25 10-53-35
# 1485.0
# 1485.0
# on way to second break
