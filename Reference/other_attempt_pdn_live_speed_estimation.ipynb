# %%
import cv2
import yt_dlp

from ultralytics import solutions
from ultralytics import YOLO

video_url = "https://www.youtube.com/watch?v=0Pg3S6s76IE"  # Youtube URL northbound

model = YOLO("yolo11n.pt")

# %%
def get_stream_url(youtube_url):
    ydl_opts = {
        'quiet': True,
        'skip_download': True,
        'no_warnings': True,
        'force_generic_extractor': False,
        'format': 'best[ext=mp4][protocol^=http]/best'
    }
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        info = ydl.extract_info(youtube_url, download=False)
        formats = info.get('formats', [info])
        # prefer video-only best mp4 OR best overall
        for f in reversed(formats):
            if f.get('vcodec', '') != 'none' and f.get('acodec', '') == 'none' and 'url' in f:
                return f['url']
        # fallback: best available format
        return formats[-1]['url']

# %%
stream_url = get_stream_url(video_url)
print("Stream URL:", stream_url)

cap = cv2.VideoCapture(stream_url)
assert cap.isOpened(), "Error reading video file"
# Out:
# Stream URL: https://manifest.googlevideo.com/api/manifest/hls_playlist/expire/1750304866/ei/ATRTaP6RPIT4u_kPkYzfGA/ip/152.122.255.5/id/0Pg3S6s76IE.2/itag/270/source/yt_live_broadcast/requiressl/yes/ratebypass/yes/live/1/sgovp/gir%3Dyes%3Bitag%3D137/rqh/1/hls_chunk_host/rr1---sn-vgqsknsk.googlevideo.com/xpc/EgVo2aDSNQ%3D%3D/playlist_duration/30/manifest_duration/30/bui/AY1jyLNnRxDEd5f3daPZ_GSYXJqwwIa9nn_TnrzACZT5Fx91yGAOPRMCpDQw2N73U7Vf-oUovepu9RZD/spc/l3OVKWU1T5MiKKbgyqc5H14rEbUdwn01hByq2u9LuucdPxq7vHw_8_3u8f7Ztw/vprv/1/playlist_type/DVR/initcwndbps/3863750/met/1750283266,/mh/sg/mm/44/mn/sn-vgqsknsk/ms/lva/mv/m/mvi/1/pl/16/rms/lva,lva/dover/13/pacing/0/short_key/1/keepalive/yes/fexp/51466697/mt/1750282844/sparams/expire,ei,ip,id,itag,source,requiressl,ratebypass,live,sgovp,rqh,xpc,playlist_duration,manifest_duration,bui,spc,vprv,playlist_type/sig/AJfQdSswRgIhAPUtzsQj5OHqI7Qb2SMvp3oe8kGKgXLtLdTL7vHe2hjIAiEA0BWnuRp07xH7P-qv55-MnH5A1txu1FlZNe7yKJsVFTY%3D/lsparams/hls_chunk_host,initcwndbps,met,mh,mm,mn,ms,mv,mvi,pl,rms/lsig/APaTxxMwRgIhAMVI_H-5EdHGeLsPrw51ikhRMWi3prxrqr263H9H4fhKAiEA8tuoWk0WAQ4IV5X-uLN1dLCdRTGRa67WRsD47esN5Q0%3D/playlist/index.m3u8

# %%
# Video writer
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))
video_writer = cv2.VideoWriter("speed_management.avi", cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

# the line after which we want to calculate speed
line_y_cross = [(550, 500), (1250,500)]  # Red line position

# Pass region as dictionary
region_points = [(550, 50), (1250, 50), (550, 950), (1250, 950)]

# Initialize speed estimation object
speedestimator = solutions.SpeedEstimator(
    show=True,  # display the output
    region = region_points,
    model="yolo11n.pt",  # path to the YOLO11 model file.
    fps=fps,  # adjust speed based on frame per second
    # max_speed=120,  # cap speed to a max value (km/h) to avoid outliers
    # max_hist=5,  # minimum frames object tracked before computing speed
    # meter_per_pixel=0.05,  # highly depends on the camera configuration
    classes=[2, 3, 5, 6, 7],  # estimate speed of specific classes.
    line_width=1  # adjust the line width for bounding boxes
)
# Out:
# Ultralytics Solutions:  {'source': None, 'model': 'yolo11n.pt', 'classes': [2, 3, 5, 6, 7], 'show_conf': True, 'show_labels': True, 'region': [(550, 50), (1250, 50), (550, 950), (1250, 950)], 'colormap': 21, 'show_in': True, 'show_out': True, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'figsize': (12.8, 7.2), 'blur_ratio': 0.5, 'vision_point': (20, 20), 'crop_dir': 'cropped-detections', 'json_file': None, 'line_width': 1, 'records': 5, 'fps': 30, 'max_hist': 5, 'meter_per_pixel': 0.05, 'max_speed': 120, 'show': True, 'iou': 0.7, 'conf': 0.25, 'device': None, 'max_det': 300, 'half': False, 'tracker': 'botsort.yaml', 'verbose': True, 'data': 'images'}

# %%
# Process video
while cap.isOpened():
    success, im0 = cap.read()

    if not success:
        print("Video frame is empty or processing is complete.")
        break

    tracks = model.track(im0, persist=True,show=False)
    results = speedestimator(im0)

    # print(results)  # access the output

    video_writer.write(results.plot_im)  # write the processed frame.

    # Exit loop if 'q' key is pressed
    if 0xFF == ord('q'): 
        # Release resources on way out of while loop
        print("manually quitting")
        break

cap.release()
video_writer.release()
cv2.destroyAllWindows()  # destroy all opened windows
# Out:
# 0: 384x640 11 cars, 1 truck, 100.9ms
# Speed: 3.0ms preprocess, 100.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 1080x1920 33.9ms
# Speed: 165.3ms track, 33.9ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 11 cars, 1 truck, 86.5ms
# Speed: 2.8ms preprocess, 86.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1: 1080x1920 8.4ms
# Speed: 124.8ms track, 8.4ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 11 cars, 1 truck, 89.2ms
# Speed: 2.3ms preprocess, 89.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 2: 1080x1920 5.9ms
# Speed: 124.7ms track, 5.9ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 11 cars, 1 truck, 91.3ms
# Speed: 2.1ms preprocess, 91.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 3: 1080x1920 4.4ms
# Speed: 131.7ms track, 4.4ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 11 cars, 1 truck, 93.2ms
# Speed: 2.1ms preprocess, 93.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 4: 1080x1920 5.5ms
# Speed: 127.0ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 11 cars, 1 truck, 90.8ms
# Speed: 2.1ms preprocess, 90.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 5: 1080x1920 7.5ms
# Speed: 127.1ms track, 7.5ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 11 cars, 1 truck, 103.7ms
# Speed: 2.3ms preprocess, 103.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 6: 1080x1920 6.1ms
# Speed: 132.4ms track, 6.1ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 11 cars, 1 truck, 95.5ms
# Speed: 2.5ms preprocess, 95.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 7: 1080x1920 6.1ms
# Speed: 125.4ms track, 6.1ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 11 cars, 1 truck, 96.4ms
# Speed: 2.0ms preprocess, 96.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 8: 1080x1920 12.2ms
# Speed: 184.8ms track, 12.2ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 11 cars, 1 truck, 127.5ms
# Speed: 3.6ms preprocess, 127.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 9: 1080x1920 17.4ms
# Speed: 153.9ms track, 17.4ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 11 cars, 1 truck, 108.7ms
# Speed: 2.1ms preprocess, 108.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 10: 1080x1920 15.2ms
# Speed: 136.4ms track, 15.2ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 11 cars, 1 truck, 96.6ms
# Speed: 2.3ms preprocess, 96.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 11: 1080x1920 8.4ms
# Speed: 123.0ms track, 8.4ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 11 cars, 1 truck, 97.4ms
# Speed: 2.2ms preprocess, 97.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 12: 1080x1920 5.9ms
# Speed: 124.3ms track, 5.9ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 11 cars, 1 truck, 83.1ms
# Speed: 3.1ms preprocess, 83.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 13: 1080x1920 5.8ms
# Speed: 128.0ms track, 5.8ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 11 cars, 1 truck, 98.8ms
# Speed: 2.6ms preprocess, 98.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 14: 1080x1920 5.8ms
# Speed: 127.6ms track, 5.8ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 11 cars, 1 truck, 119.4ms
# Speed: 2.6ms preprocess, 119.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 15: 1080x1920 5.6ms
# Speed: 127.4ms track, 5.6ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 11 cars, 1 truck, 96.0ms
# Speed: 2.1ms preprocess, 96.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 16: 1080x1920 4.6ms
# Speed: 115.6ms track, 4.6ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 11 cars, 1 truck, 82.2ms
# Speed: 2.4ms preprocess, 82.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 17: 1080x1920 4.8ms
# Speed: 114.8ms track, 4.8ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 11 cars, 1 truck,
7ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 15 cars, 91.7ms
# Speed: 2.1ms preprocess, 91.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 547: 1080x1920 5.5ms
# Speed: 134.0ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 15 cars, 98.1ms
# Speed: 3.0ms preprocess, 98.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 548: 1080x1920 6.8ms
# Speed: 134.5ms track, 6.8ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 15 cars, 95.6ms
# Speed: 2.0ms preprocess, 95.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 549: 1080x1920 6.3ms
# Speed: 134.1ms track, 6.3ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 15 cars, 109.1ms
# Speed: 2.2ms preprocess, 109.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# 550: 1080x1920 5.8ms
# Speed: 144.9ms track, 5.8ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 15 cars, 98.6ms
# Speed: 2.2ms preprocess, 98.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 551: 1080x1920 6.6ms
# Speed: 135.5ms track, 6.6ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 15 cars, 97.5ms
# Speed: 2.2ms preprocess, 97.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 552: 1080x1920 6.5ms
# Speed: 141.3ms track, 6.5ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 15 cars, 101.6ms
# Speed: 2.0ms preprocess, 101.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 553: 1080x1920 7.3ms
# Speed: 144.7ms track, 7.3ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 15 cars, 111.4ms
# Speed: 2.4ms preprocess, 111.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 554: 1080x1920 7.3ms
# Speed: 161.6ms track, 7.3ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 15 cars, 103.1ms
# Speed: 2.1ms preprocess, 103.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 555: 1080x1920 6.3ms
# Speed: 142.3ms track, 6.3ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 15 cars, 102.6ms
# Speed: 2.1ms preprocess, 102.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 556: 1080x1920 5.3ms
# Speed: 140.3ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 15 cars, 95.0ms
# Speed: 2.3ms preprocess, 95.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 557: 1080x1920 37.7ms
# Speed: 128.3ms track, 37.7ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 15 cars, 117.5ms
# Speed: 3.3ms preprocess, 117.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 558: 1080x1920 133.5ms
# Speed: 154.8ms track, 133.5ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 15 cars, 115.7ms
# Speed: 2.4ms preprocess, 115.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 559: 1080x1920 6.8ms
# Speed: 139.3ms track, 6.8ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 15 cars, 93.3ms
# Speed: 2.1ms preprocess, 93.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 560: 1080x1920 7.7ms
# Speed: 136.3ms track, 7.7ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 15 cars, 93.1ms
# Speed: 2.4ms preprocess, 93.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 561: 1080x1920 37.0ms
# Speed: 133.5ms track, 37.0ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 15 cars, 121.0ms
# Speed: 3.2ms preprocess, 121.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 562: 1080x1920 109.5ms
# Speed: 142.4ms track, 109.5ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 15 cars, 117.0ms
# Speed: 2.6ms preprocess, 117.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 563: 1080x1920 9.9ms
# Speed: 144.2ms track, 9.9ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 15 cars, 95.4ms
# Speed: 2.2ms preprocess, 95.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 564: 1080x1920 37.6ms
# Speed: 128.0ms track, 37.6ms solution per image at shape (1, 3, 1080, 1920)
#
#
# 0: 384x640 15 cars, 115.0ms
# Speed: 2.2ms preprocess, 115.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 10
#       7     break
#       9 tracks = model.track(im0, persist=True,show=False)
# ---> 10 results = speedestimator(im0)
#      12 # print(results)  # access the output
#      14 video_writer.write(results.plot_im)  # write the processed frame.
#
# File c:\Users\Nineveh.OConnell\AppData\Local\anaconda3\envs\border_env\Lib\site-packages\ultralytics\solutions\solutions.py:247, in BaseSolution.__call__(self, *args, **kwargs)
#     245 """Allow instances to be called like a function with flexible arguments."""
#     246 with self.profilers[1]:
# --> 247     result = self.process(*args, **kwargs)  # Call the subclass-specific process method
#     248 track_or_predict = "predict" if type(self).__name__ == "ObjectCropper" else "track"
#     249 track_or_predict_speed = self.profilers[0].dt * 1e3
#
# File c:\Users\Nineveh.OConnell\AppData\Local\anaconda3\envs\border_env\Lib\site-packages\ultralytics\solutions\speed_estimation.py:80, in SpeedEstimator.process(self, im0)
#      64 """
#      65 Process an input frame to estimate object speeds based on tracking data.
#      66
#    (...)     77     >>> results = estimator.process(image)
#      78 """
#      79 self.frame_count += 1
# ---> 80 self.extract_tracks(im0)
#      81 annotator = SolutionAnnotator(im0, line_width=self.line_width)
#      83 for box, track_id, _, _ in zip(self.boxes, self.track_ids, self.clss, self.confs):
#
# File c:\Users\Nineveh.OConnell\AppData\Local\anaconda3\envs\border_env\Lib\site-packages\ultralytics\solutions\solutions.py:171, in BaseSolution.extract_tracks(self, im0)
#     159 """
#     160 Apply object tracking and extract tracks from an input image or frame.
#     161
#    (...)    168     >>> solution.extract_tracks(frame)
#     169 """
#     170 with self.profilers[0]:
# --> 171     self.tracks = self.model.track(
#     172         source=im0, persist=True, classes=self.classes, verbose=False, **self.track_add_args
#     173     )[0]
#     174 is_obb = self.tracks.obb is not None
#     175 self.track_data = self.tracks.obb if is_obb else self.tracks.boxes  # Extract tracks for OBB or object detection
#
# File c:\Users\Nineveh.OConnell\AppData\Local\anaconda3\envs\border_env\Lib\site-packages\ultralytics\engine\model.py:599, in Model.track(self, source, stream, persist, **kwargs)
#     597 kwargs["batch"] = kwargs.get("batch") or 1  # batch-size 1 for tracking in videos
#     598 kwargs["mode"] = "track"
# --> 599 return self.predict(source=source, stream=stream, **kwargs)
#
# File c:\Users\Nineveh.OConnell\AppData\Local\anaconda3\envs\border_env\Lib\site-packages\ultralytics\engine\model.py:555, in Model.predict(self, source, stream, predictor, **kwargs)
#     553 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     554     self.predictor.set_prompts(prompts)
# --> 555 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File c:\Users\Nineveh.OConnell\AppData\Local\anaconda3\envs\border_env\Lib\site-packages\ultralytics\engine\predictor.py:227, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     225     return self.stream_inference(source, model, *args, **kwargs)
#     226 else:
# --> 227     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File c:\Users\Nineveh.OConnell\AppData\Local\anaconda3\envs\border_env\Lib\site-packages\torch\utils\_contextlib.py:36, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      33 try:
#      34     # Issuing `None` to a generator fires it up
#      35     with ctx_factory():
# ---> 36         response = gen.send(None)
#      38     while True:
#      39         try:
#      40             # Forward the response to our caller and get its next request
#
# File c:\Users\Nineveh.OConnell\AppData\Local\anaconda3\envs\border_env\Lib\site-packages\ultralytics\engine\predictor.py:338, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     336 with profilers[2]:
#     337     self.results = self.postprocess(preds, im, im0s)
# --> 338 self.run_callbacks("on_predict_postprocess_end")
#     340 # Visualize, save, write results
#     341 n = len(im0s)
#
# File c:\Users\Nineveh.OConnell\AppData\Local\anaconda3\envs\border_env\Lib\site-packages\ultralytics\engine\predictor.py:507, in BasePredictor.run_callbacks(self, event)
#     505 """Run all registered callbacks for a specific event."""
#     506 for callback in self.callbacks.get(event, []):
# --> 507     callback(self)
#
# File c:\Users\Nineveh.OConnell\AppData\Local\anaconda3\envs\border_env\Lib\site-packages\ultralytics\trackers\track.py:95, in on_predict_postprocess_end(predictor, persist)
#      92     predictor.vid_path[i if is_stream else 0] = vid_path
#      94 det = (result.obb if is_obb else result.boxes).cpu().numpy()
# ---> 95 tracks = tracker.update(det, result.orig_img, getattr(result, "feats", None))
#      96 if len(tracks) == 0:
#      97     continue
#
# File c:\Users\Nineveh.OConnell\AppData\Local\anaconda3\envs\border_env\Lib\site-packages\ultralytics\trackers\byte_tracker.py:339, in BYTETracker.update(self, results, img, feats)
#     336 if hasattr(self, "gmc") and img is not None:
#     337     # use try-except here to bypass errors from gmc module
#     338     try:
# --> 339         warp = self.gmc.apply(img, dets)
#     340     except Exception:
#     341         warp = np.eye(2, 3)
#
# File c:\Users\Nineveh.OConnell\AppData\Local\anaconda3\envs\border_env\Lib\site-packages\ultralytics\trackers\utils\gmc.py:115, in GMC.apply(self, raw_frame, detections)
#     113     return self.apply_ecc(raw_frame)
#     114 elif self.method == "sparseOptFlow":
# --> 115     return self.apply_sparseoptflow(raw_frame)
#     116 else:
#     117     return np.eye(2, 3)
#
# File c:\Users\Nineveh.OConnell\AppData\Local\anaconda3\envs\border_env\Lib\site-packages\ultralytics\trackers\utils\gmc.py:295, in GMC.apply_sparseoptflow(self, raw_frame)
#     278 """
#     279 Apply Sparse Optical Flow method to a raw frame.
#     280
#    (...)    292      [0. 1. 0.]]
#     293 """
#     294 height, width, c = raw_frame.shape
# --> 295 frame = cv2.cvtColor(raw_frame, cv2.COLOR_BGR2GRAY) if c == 3 else raw_frame
#     296 H = np.eye(2, 3)
#     298 # Downscale image for computational efficiency
#
# KeyboardInterrupt:
